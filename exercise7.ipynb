# %%
# 7a

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import numpy as np

gamma = 0.0012
C = 0.85

# Set random seed for reproducibility
seed = 42
np.random.seed(seed)

# Load digits dataset
digits = load_digits()
X, y = digits.data, digits.target

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

# Fit
svc = SVC(kernel='rbf', gamma=gamma, C=C)
svc.fit(X_train, y_train)

# Predict
predictions = svc.predict(X_test)
acc = (predictions == y_test).sum() / len(X_test)

np.round(acc, 2)

# %%
# 7c

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import numpy as np

gamma = 0.0012
C = 0.85

# Set random seed for reproducibility
seed = 42
np.random.seed(seed)

# Load digits dataset
digits = load_digits()
X, y = digits.data, digits.target

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

# Fit
svc = SVC(kernel='rbf', gamma=gamma, C=C)
svc.fit(X_train, y_train)

svc.n_support_[:2].sum()

# %%
# 7d part 1

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import numpy as np

gamma = 0.0012
C = 0.85

# Set random seed for reproducibility
seed = 42
np.random.seed(seed)

# Load digits dataset
digits = load_digits()
X, y = digits.data, digits.target

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

# Fit
svc = SVC(kernel='rbf', gamma=gamma, C=C)
svc.fit(X_train, y_train)

svs0 = svc.support_vectors_[0:svc.n_support_[0]]
svs1 = svc.support_vectors_[len(svs0):len(svs0) + svc.n_support_[1]]
svs0, svs1

# %%
# 7d part 2

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import numpy as np

gamma = 0.0012
C = 0.85

# Set random seed for reproducibility
seed = 42
np.random.seed(seed)

# Load digits dataset
digits = load_digits()
X, y = digits.data, digits.target

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

# Fit
svc = SVC(kernel='rbf', gamma=gamma, C=C)
svc.fit(X_train, y_train)

sv = svc.support_vectors_[:svc.n_support_[1]]
preds = svc.decision_function(sv)

lowest = sorted([(preds[y][0], y) for y in range(len(preds))])
[sv[i].reshape(8, 8) for _, i in lowest[:4]]

for _, i in lowest[:4]:
    print(sv[i].reshape(8, 8))
    print("")

# %%
# 7e

from sklearn.datasets import load_digits
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.svm import SVC
import numpy as np

gamma = 0.0012
C = 0.85

# Set random seed for reproducibility
seed = 42
np.random.seed(seed)

# Load digits dataset
digits = load_digits()
X, y = digits.data, digits.target

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

param_grid = {
    'C': [0.6, 0.8, 1, 2, 3, 4, 6], 
    'gamma': [0.0001, 0.0006, 0.001, 0.006], 
    'kernel': ['rbf']
} 

svc = SVC(kernel='rbf', gamma=gamma, C=C)
grid = GridSearchCV(svc, param_grid, refit = True, cv = 5, scoring='accuracy') 
grid.fit(X_train, y_train)

grid.best_params_, np.round(grid.score(X_test, y_test), 2)
